# %%
import gradio as gr

# %%
# 1. The Logic: A simple function
def greet(name):
    return f"Hello {name}! Welcome to Gradio."

# %%
demo = gr.Interface(fn=greet, inputs="text", outputs="text")

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://7f5729fe3eca6cb9fe.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7f5729fe3eca6cb9fe.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

def reverse_text(text):
    return text[::-1]

demo = gr.Interface(
    fn=reverse_text,
    inputs="text",
    outputs="text",
    title="Text Reverser App",
    description="This app demonstrates how to use custom Textbox components."
)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://28350c9e97bc4d7dac.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://28350c9e97bc4d7dac.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

def calculate_tip(bill_amount, tip_percentage):
    tip = bill_amount * (tip_percentage / 100)
    total = bill_amount + tip
    return f"Tip Amount: ${tip:.2f}", f"Total Bill: ${total:.2f}"

# %%
calculate_tip(600, 4)
# Out:
# ('Tip Amount: $24.00', 'Total Bill: $624.00')

# %%
demo = gr.Interface(
    fn=calculate_tip,

    # Pass a LIST of inputs
    inputs=[
        gr.Number(label="Bill Amount ($)"),
        gr.Slider(minimum=0, maximum=30, value=15, label="Tip %")
    ],

    # Pass a LIST of outputs
    outputs=[
        gr.Textbox(label="Tip"),
        gr.Textbox(label="Total")
    ],

    title="Tip Calculator"
)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ddf5e53a1970cf4cb5.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ddf5e53a1970cf4cb5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
